# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import seaborn as sns
import pandas as pd

# %%
df = sns.load_dataset("iris")

# %%
df.shape
# Out:
# (150, 5)

# %%
df.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 44            5.1          3.8           1.9          0.4      setosa
# 125           7.2          3.2           6.0          1.8   virginica
# 19            5.1          3.8           1.5          0.3      setosa
# 93            5.0          2.3           3.3          1.0  versicolor
# 95            5.7          3.0           4.2          1.2  versicolor

# %%
X = df.iloc[:,0:4]
y = df.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (135, 4)
# (15, 4)

# %%
clf_tree = DecisionTreeClassifier(splitter='random',max_depth=4)

# %%
clf_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, splitter='random')

# %%
ypred = clf_tree.predict(X_test)

# %%
print(accuracy_score(y_test,ypred))
# Out:
# 0.9333333333333333

# %%
from sklearn import tree

# %%
print(tree.plot_tree(clf_tree))
# Out:
# [Text(0.4642857142857143, 0.9, 'x[3] <= 1.409\ngini = 0.666\nsamples = 135\nvalue = [46, 42, 47]'), Text(0.14285714285714285, 0.7, 'x[2] <= 2.639\ngini = 0.491\nsamples = 77\nvalue = [46, 30, 1]'), Text(0.3035714285714286, 0.8, 'True  '), Text(0.07142857142857142, 0.5, 'gini = 0.0\nsamples = 46\nvalue = [46, 0, 0]'), Text(0.21428571428571427, 0.5, 'x[3] <= 1.105\ngini = 0.062\nsamples = 31\nvalue = [0, 30, 1]'), Text(0.14285714285714285, 0.3, 'gini = 0.0\nsamples = 9\nvalue = [0, 9, 0]'), Text(0.2857142857142857, 0.3, 'x[3] <= 1.39\ngini = 0.087\nsamples = 22\nvalue = [0, 21, 1]'), Text(0.21428571428571427, 0.1, 'gini = 0.0\nsamples = 15\nvalue = [0, 15, 0]'), Text(0.35714285714285715, 0.1, 'gini = 0.245\nsamples = 7\nvalue = [0, 6, 1]'), Text(0.7857142857142857, 0.7, 'x[3] <= 2.016\ngini = 0.328\nsamples = 58\nvalue = [0, 12, 46]'), Text(0.625, 0.8, '  False'), Text(0.7142857142857143, 0.5, 'x[3] <= 1.672\ngini = 0.444\nsamples = 36\nvalue = [0, 12, 24]'), Text(0.5714285714285714, 0.3, 'x[2] <= 5.21\ngini = 0.278\nsamples = 12\nvalue = [0, 10, 2]'), Text(0.5, 0.1, 'gini = 0.165\nsamples = 11\nvalue = [0, 10, 1]'), Text(0.6428571428571429, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'), Text(0.8571428571428571, 0.3, 'x[3] <= 1.796\ngini = 0.153\nsamples = 24\nvalue = [0, 2, 22]'), Text(0.7857142857142857, 0.1, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'), Text(0.9285714285714286, 0.1, 'gini = 0.087\nsamples = 22\nvalue = [0, 1, 21]'), Text(0.8571428571428571, 0.5, 'gini = 0.0\nsamples = 22\nvalue = [0, 0, 22]')]
