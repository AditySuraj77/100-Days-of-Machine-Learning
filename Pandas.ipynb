# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Data/Match.csv')

# %%
data.head()
# Out:
#    Match_SK  match_id                        Team1  \
# 0         0    335987  Royal Challengers Bangalore
# 1         1    335988              Kings XI Punjab
# 2         2    335989             Delhi Daredevils
# 3         3    335990               Mumbai Indians
# 4         4    335991        Kolkata Knight Riders
#
#                          Team2 match_date  Season_Year  \
# 0        Kolkata Knight Riders  4/18/2008         2008
# 1          Chennai Super Kings  4/19/2008         2008
# 2             Rajasthan Royals  4/19/2008         2008
# 3  Royal Challengers Bangalore  4/20/2008         2008
# 4              Deccan Chargers  4/20/2008         2008
#
#                                    Venue_Name   City_Name Country_Name  \
# 0                       M Chinnaswamy Stadium   Bangalore        India
# 1  Punjab Cricket Association Stadium, Mohali  Chandigarh        India
# 2                            Feroz Shah Kotla       Delhi        India
# ...

# %%
data.shape
# Out:
# (637, 17)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 637 entries, 0 to 636
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Match_SK      637 non-null    int64
#  1   match_id      637 non-null    int64
#  2   Team1         637 non-null    object
#  3   Team2         637 non-null    object
#  4   match_date    637 non-null    object
#  5   Season_Year   637 non-null    int64
#  6   Venue_Name    636 non-null    object
#  7   City_Name     637 non-null    object
#  8   Country_Name  637 non-null    object
#  9   Toss_Winner   636 non-null    object
#  10  match_winner  634 non-null    object
#  11  Toss_Name     636 non-null    object
#  12  Win_Type      635 non-null    object
#  13  Outcome_Type  637 non-null    object
#  14  ManOfMach     633 non-null    object
#  15  Win_Margin    628 non-null    float64
#  16  Country_id    637 non-null    int64
# dtypes: float64(1), int64(4), object(12)
# ...

# %%
data.describe()
# Out:
#          Match_SK      match_id  Season_Year  Win_Margin  Country_id
# count  637.000000  6.370000e+02   637.000000  628.000000  637.000000
# mean   318.000000  6.378825e+05  2012.497645   17.272293    1.152276
# std    184.030342  2.356312e+05     2.776600   22.212632    0.438388
# min      0.000000  3.359870e+05  2008.000000    0.000000    1.000000
# 25%    159.000000  4.191550e+05  2010.000000    6.000000    1.000000
# 50%    318.000000  5.483830e+05  2012.000000    8.000000    1.000000
# 75%    477.000000  8.297480e+05  2015.000000   20.000000    1.000000
# max    636.000000  1.082650e+06  2017.000000  146.000000    3.000000

# %%
data['match_winner']
# Out:
# 0            Kolkata Knight Riders
# 1              Chennai Super Kings
# 2                 Delhi Daredevils
# 3      Royal Challengers Bangalore
# 4            Kolkata Knight Riders
#                   ...
# 632    Royal Challengers Bangalore
# 633        Rising Pune Supergiants
# 634          Kolkata Knight Riders
# 635                 Mumbai Indians
# 636                 Mumbai Indians
# Name: match_winner, Length: 637, dtype: object

# %%
data[['Team1','Team2','match_winner']]
# Out:
#                            Team1                        Team2  \
# 0    Royal Challengers Bangalore        Kolkata Knight Riders
# 1                Kings XI Punjab          Chennai Super Kings
# 2               Delhi Daredevils             Rajasthan Royals
# 3                 Mumbai Indians  Royal Challengers Bangalore
# 4          Kolkata Knight Riders              Deccan Chargers
# ..                           ...                          ...
# 632             Delhi Daredevils  Royal Challengers Bangalore
# 633               Mumbai Indians      Rising Pune Supergiants
# 634          Sunrisers Hyderabad        Kolkata Knight Riders
# 635               Mumbai Indians        Kolkata Knight Riders
# 636               Mumbai Indians      Rising Pune Supergiants
#
#                     match_winner
# 0          Kolkata Knight Riders
# 1            Chennai Super Kings
# 2               Delhi Daredevils
# 3    Royal Challengers Bangalore
# 4          Kolkata Knight Riders
# ...

# %%
data.iloc[0:3]
# Out:
#    Match_SK  match_id                        Team1                  Team2  \
# 0         0    335987  Royal Challengers Bangalore  Kolkata Knight Riders
# 1         1    335988              Kings XI Punjab    Chennai Super Kings
# 2         2    335989             Delhi Daredevils       Rajasthan Royals
#
#   match_date  Season_Year                                  Venue_Name  \
# 0  4/18/2008         2008                       M Chinnaswamy Stadium
# 1  4/19/2008         2008  Punjab Cricket Association Stadium, Mohali
# 2  4/19/2008         2008                            Feroz Shah Kotla
#
#     City_Name Country_Name                  Toss_Winner  \
# 0   Bangalore        India  Royal Challengers Bangalore
# 1  Chandigarh        India          Chennai Super Kings
# 2       Delhi        India             Rajasthan Royals
#
#             match_winner Toss_Name Win_Type Outcome_Type    ManOfMach  \
# 0  Kolkata Knight Riders     field     runs       Result  BB McCullum
# ...

# %%
data.iloc[:,2:7]
# Out:
#                            Team1                        Team2 match_date  \
# 0    Royal Challengers Bangalore        Kolkata Knight Riders  4/18/2008
# 1                Kings XI Punjab          Chennai Super Kings  4/19/2008
# 2               Delhi Daredevils             Rajasthan Royals  4/19/2008
# 3                 Mumbai Indians  Royal Challengers Bangalore  4/20/2008
# 4          Kolkata Knight Riders              Deccan Chargers  4/20/2008
# ..                           ...                          ...        ...
# 632             Delhi Daredevils  Royal Challengers Bangalore  5/14/2017
# 633               Mumbai Indians      Rising Pune Supergiants  5/16/2017
# 634          Sunrisers Hyderabad        Kolkata Knight Riders  5/17/2017
# 635               Mumbai Indians        Kolkata Knight Riders  5/19/2017
# 636               Mumbai Indians      Rising Pune Supergiants  5/21/2017
#
#      Season_Year                                  Venue_Name
# ...

# %%
data.iloc[:,[2,3,10]]
# Out:
#                            Team1                        Team2  \
# 0    Royal Challengers Bangalore        Kolkata Knight Riders
# 1                Kings XI Punjab          Chennai Super Kings
# 2               Delhi Daredevils             Rajasthan Royals
# 3                 Mumbai Indians  Royal Challengers Bangalore
# 4          Kolkata Knight Riders              Deccan Chargers
# ..                           ...                          ...
# 632             Delhi Daredevils  Royal Challengers Bangalore
# 633               Mumbai Indians      Rising Pune Supergiants
# 634          Sunrisers Hyderabad        Kolkata Knight Riders
# 635               Mumbai Indians        Kolkata Knight Riders
# 636               Mumbai Indians      Rising Pune Supergiants
#
#                     match_winner
# 0          Kolkata Knight Riders
# 1            Chennai Super Kings
# 2               Delhi Daredevils
# 3    Royal Challengers Bangalore
# 4          Kolkata Knight Riders
# ...

# %%
data.iloc[[1,4,5]]
# Out:
#    Match_SK  match_id                  Team1                Team2 match_date  \
# 1         1    335988        Kings XI Punjab  Chennai Super Kings  4/19/2008
# 4         4    335991  Kolkata Knight Riders      Deccan Chargers  4/20/2008
# 5         5    335992       Rajasthan Royals      Kings XI Punjab  4/21/2008
#
#    Season_Year                                  Venue_Name   City_Name  \
# 1         2008  Punjab Cricket Association Stadium, Mohali  Chandigarh
# 4         2008                                Eden Gardens     Kolkata
# 5         2008                      Sawai Mansingh Stadium      Jaipur
#
#   Country_Name          Toss_Winner           match_winner Toss_Name Win_Type  \
# 1        India  Chennai Super Kings    Chennai Super Kings       bat     runs
# 4        India      Deccan Chargers  Kolkata Knight Riders       bat  wickets
# 5        India      Kings XI Punjab       Rajasthan Royals       bat  wickets
#
#   Outcome_Type   ManOfMach  Win_Margin  Country_id
# ...

# %%
mask = data['City_Name'] == 'Kolkata'
data[mask].shape
# Out:
# (61, 17)

# %%
def get_city_of_match(city):
    mask = data['City_Name'] == city
    return data[mask].shape

# %%
get_city_of_match('Chandigarh')
get_city_of_match('Jaipur')
# Out:
# (33, 17)

# %%
mask1 = data['Toss_Winner']== 'Deccan Chargers'
mask2 = data['match_winner'] == 'Deccan Chargers'

data[mask1 & mask2].shape
# Out:
# (19, 17)

# %%
data['Toss_Winner'].value_counts()
# Out:
# Toss_Winner
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Rising Pune Supergiants        12
# Kochi Tuskers Kerala            8
# Rising Pune Supergiant          1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data['Toss_Winner'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Toss_Winner'>

# %%
data['Venue_Name'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data['Win_Margin'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
series = data['Team1'].value_counts()
series2 = data['Team2'].value_counts()

# %%
series['Kings XI Punjab'] + series2['Kings XI Punjab']
# Out:
# 148

# %%
data.sort_values('Venue_Name',ascending=True).head()
# Out:
#      Match_SK  match_id                  Team1                  Team2  \
# 437       437    734014  Kolkata Knight Riders         Mumbai Indians
# 277       277    548340        Deccan Chargers  Kolkata Knight Riders
# 288       288    548353        Deccan Chargers          Pune Warriors
# 426       426    733992        Kings XI Punjab    Chennai Super Kings
# 126       126    419122        Deccan Chargers        Kings XI Punjab
#
#     match_date  Season_Year        Venue_Name City_Name Country_Name  \
# 437  5/14/2014         2014  Barabati Stadium   Cuttack        India
# 277  4/22/2012         2012  Barabati Stadium   Cuttack        India
# 288   5/1/2012         2012  Barabati Stadium   Cuttack        India
# 426   5/7/2014         2014  Barabati Stadium   Cuttack        India
# 126  3/19/2010         2010  Barabati Stadium   Cuttack        India
#
#                Toss_Winner           match_winner Toss_Name Win_Type  \
# ...

# %%
data.sort_values(['Venue_Name','match_date'],ascending=True).head()
# Out:
#      Match_SK  match_id            Team1                  Team2 match_date  \
# 126       126    419122  Deccan Chargers        Kings XI Punjab  3/19/2010
# 129       129    419125  Deccan Chargers       Delhi Daredevils  3/21/2010
# 277       277    548340  Deccan Chargers  Kolkata Knight Riders  4/22/2012
# 288       288    548353  Deccan Chargers          Pune Warriors   5/1/2012
# 431       431    734002  Kings XI Punjab  Kolkata Knight Riders  5/11/2014
#
#      Season_Year        Venue_Name City_Name Country_Name  \
# 126         2010  Barabati Stadium   Cuttack        India
# 129         2010  Barabati Stadium   Cuttack        India
# 277         2012  Barabati Stadium   Cuttack        India
# 288         2012  Barabati Stadium   Cuttack        India
# 431         2014  Barabati Stadium   Cuttack        India
#
#                Toss_Winner           match_winner Toss_Name Win_Type  \
# 126        Kings XI Punjab        Deccan Chargers     field     runs
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['Venue_Name'].duplicated().sum()
# Out:
# 599

# %%
new = data.drop_duplicates(subset=['Venue_Name'])

# %%
new.Venue_Name.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### GroupBy

# %%
df = pd.read_csv("Data/deliveries.csv/deliveries.csv")

# %%
df.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
batsman = df.groupby('batter')

# %%
batsman['batsman_runs'].sum().sort_values(ascending=False).head(10)
# Out:
# batter
# V Kohli           8014
# S Dhawan          6769
# RG Sharma         6630
# DA Warner         6567
# SK Raina          5536
# MS Dhoni          5243
# AB de Villiers    5181
# CH Gayle          4997
# RV Uthappa        4954
# KD Karthik        4843
# Name: batsman_runs, dtype: int64

# %%
most_four = df['batsman_runs'] == 4
newdata = df[most_four]

# %%
newdata.shape[0]
# Out:
# 29850

# %%
newdata.groupby("batter")['batsman_runs'].count().sort_values(ascending=False)
# Out:
# batter
# S Dhawan        768
# V Kohli         708
# DA Warner       663
# RG Sharma       599
# SK Raina        506
#                ...
# B Stanlake        1
# J Theron          1
# SH Johnson        1
# SD Lad            1
# DE Bollinger      1
# Name: batsman_runs, Length: 538, dtype: int64

# %%
vk = df[df['batter'] == 'V Kohli']

# %%
vk.groupby("bowling_team")['batsman_runs'].sum().sort_values(ascending=False).head(5)
# Out:
# bowling_team
# Chennai Super Kings      1053
# Kolkata Knight Riders     962
# Mumbai Indians            860
# Sunrisers Hyderabad       767
# Rajasthan Royals          764
# Name: batsman_runs, dtype: int64

# %%
data.head()
# Out:
#    Match_SK  match_id                        Team1  \
# 0         0    335987  Royal Challengers Bangalore
# 1         1    335988              Kings XI Punjab
# 2         2    335989             Delhi Daredevils
# 3         3    335990               Mumbai Indians
# 4         4    335991        Kolkata Knight Riders
#
#                          Team2 match_date  Season_Year  \
# 0        Kolkata Knight Riders  4/18/2008         2008
# 1          Chennai Super Kings  4/19/2008         2008
# 2             Rajasthan Royals  4/19/2008         2008
# 3  Royal Challengers Bangalore  4/20/2008         2008
# 4              Deccan Chargers  4/20/2008         2008
#
#                                    Venue_Name   City_Name Country_Name  \
# 0                       M Chinnaswamy Stadium   Bangalore        India
# 1  Punjab Cricket Association Stadium, Mohali  Chandigarh        India
# 2                            Feroz Shah Kotla       Delhi        India
# ...

# %% [markdown]
# ### Pivot Table

# %%
df.head(5)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
mask = df['batsman_runs'] == 6
six = df[mask]
six.shape
# Out:
# (13051, 17)

# %%
pt = six.pivot_table(index='over',columns='batting_team',values='batsman_runs',aggfunc='count')

# %%
import seaborn as sns

# %%
sns.heatmap(pt)
# Out:
# <Axes: xlabel='batting_team', ylabel='over'>

# %%
titanic = pd.read_csv('Data/titanic.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.Age.mean()
# Out:
# 29.69911764705882

# %%
titanic['Age'].fillna(titanic.Age.mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64
